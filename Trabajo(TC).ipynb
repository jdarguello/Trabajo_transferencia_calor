# %% [markdown]
# <div align="justify">
#     <h2 align="center"><strong>Universidad Industrial de Santander</strong></h2>
#     <h2 align="center">Trabajo <i> TRANSFERENCIA DE CALOR </i></h2>
#     <h2 align="center"><strong>Diseño de un Termo Termico</strong>.</h2>
# </div>

# %% [markdown]
# ## Elvis Pinzón Acuña

# %% [markdown]
# ##### __Resumen__
#
# En este trabajo se explicó el diseño de un termo térmico hecho de un material altamente conductor y de paredes delgadas, mediante el análisis de parámetros; conductividad térmica [ⱪ], condiciones externas y propiedades mecánicas, obteniendo así un modelamiento matemático que nos permita controlar la variación de temperatura en función del tiempo.
#
# A continuación, expondremos los conocimientos requeridos para llevar a cabo dicho estudio y como mediante estos, logramos mantener un punto de ajuste, al sintetizar las variables en un laboratorio programado en software PYTHON, permitiendo regenerar las condiciones deseadas en el líquido de forma uniforme; que nuestra finalidad del proyecto.

# %% [markdown]
# ##### __Palabras clave__: Diseño,

# %% [markdown]
# ##### __1. Introduccion__
#
# La utilización de software libres en nuestra actualidad ha tomado un auge gracias a que nos permite optimizar los procesos, así como también apoya la toma de decisiones cuando se trata de una situación real, siendo hoy una herramienta básica de construcción y más utilizados en la ingeniería, logrando de forma efectiva la resolución de los problemas que nos hacen frente en la industria; hacemos uso de esta herramienta para hacer un sistema de control que nos permita hacer la ejecución deseada del propio usuario, al sinterizar los parámetros de diseño influenciados por factores externos, desarrollado a través de un algoritmo que permite mantener dentro de un rango optimo en la distribución de temperatura designada al permanecer interactuando con las condiciones externas, estos datos primarios obtenidos son llevados a la función lógica que muestra la interacción que existe entre ellas manifestadas de forma gradual (se está enfriando el líquido interno), con lo cual es posible fijar un valor mínimo para la variable temperatura y al observar que estos valores se acercan a ese límite permitido puedan ser regenerados (calor perdido) en nuestro caso por una resistencia para satisfacer los requerimientos funcionales y los mismos puedan ser mantenidos en sus límites tolerables. Una vez se seleccionen el objetivo según sus requerimientos y las variables independientes, se procede a ensamblar el modelo que describa cómo se relacionan las variables del problema y cómo el criterio de rendimiento (temperatura) es influenciado en función del tiempo. Este contenido nos permite la validación de mantener el líquido caliente dentro del termo térmico cuando está abierto el mayor tiempo posible

# %% [markdown]
# ##### __2. Conocimientos previos requeridos__

# %% [markdown]
# ##### __2.1. Conductividad termica__
#
# Por la ley de Fourier, la conductividad térmica se define como;
# \begin{equation}
#     k = - \frac{q''_x}{\frac{\partial T}{\partial x}}
# \end{equation}
#
# Se sigue que, para un gradiente de temperatura establecido, el flujo de calor por conducción aumenta con el incremento de la conductividad térmica. Recordando el mecanismo físico asociado con la conducción, se tiene que, en general, la conductividad térmica de un sólido es mayor que la de un líquido, que a su vez es mayor que la de un gas. La conductividad térmica de un sólido puede ser más de cuatro órdenes de magnitud más grande que la de un gas. Esta tendencia se debe en gran parte a las diferencias en el espacio intermolecular para los dos estados.
#
# ![image.png](attachment:e1274dcb-d393-4f97-a6d6-1f11b2c9a902.png)
#
# *Para nuestro caso la conductividad es minima
#
# ##### __2.2. Conveccion natural__
#
# La magnitud de la transferencia de calor por convección natural entre una superficie y un fluido está relacionada de manera directa con el gasto de este
# último. Entre mayor sea el gasto, más alta será la razón de la transferencia de calor. De hecho, son los gastos muy altos los que incrementan el coeficiente de transferencia de calor

# %% [markdown]
# ##### __Ecuacion del movimiento y el numero de Grashof__
#
# Perfiles típicos de velocidades y de temperaturas para el flujo de convección natural sobre una placa vertical caliente a la temperatura Ts introducida en un fluido a la temperatura T_infinito;
#
# ![image.png](attachment:29e6728a-c1c6-4b3b-9208-1868d50fbdfd.png)

# %% [markdown]
# ###### *Cantidad de movimiento
#
# \begin{equation}
#      u\frac{\partial u}{\partial x} + v\frac{\partial u}{\partial y} =  v\frac{\partial^2 u}{\partial y^2} + g\beta \left(T - T_\infty    \right)
# \end{equation}

# %% [markdown]
# ###### *Energia
# \begin{equation}
#     u\frac{\partial T}{\partial x} + v\frac{\partial T}{\partial y} = \alpha\frac{\partial ^2 T}{\partial y^2}
# \end{equation}

# %% [markdown]
# ###### *__Numero de Grashof__
# \begin{equation}
#     G_{r_{L}} = \frac{g\beta \left(T_s - T_\infty \right) L^3_c}{V^2}
# \end{equation}

# %% [markdown]
# ###### Tablas: __Conveccion sobre superficies__
#
#
# ###### *Placas verticales
#
# ![image.png](attachment:f98f4b19-d044-4b40-9e5a-5e4d7c4cff2b.png)

# %% [markdown]
# ###### *Cilindro verticales
#
# ![image.png](attachment:d33b0133-5995-4f56-97e8-91413f87cc87.png)

# %% [markdown]
# ##### __2.3. Ecuacion de la conduccion de calor__
#
# Si se descarta la radiación (o se incorpora en el coeficiente de transferencia de calor h), la razón de la transferencia de calor también se puede expresar a partir
# de la ley de Newton del enfriamiento como;

# %% [markdown]
# \begin{equation}
#     \dot{Q} = hA_s \left(T_s - T_\infty \right)
# \end{equation}

# %% [markdown]
# \begin{equation}
#     T_s = T_\infty + \frac{\dot{e}_{gen}V}{hA_s}
# \end{equation}

# %% [markdown]
# \begin{equation}
#     T_{s,pared plana} = T_\infty + \frac{\dot{e}_{gen}L}{h}
# \end{equation}

# %% [markdown]
# \begin{equation}
#     T_{s, cilindro} = T_\infty + \frac{\dot{e}_{gen}\rho_o}{2h}
# \end{equation}

# %% [markdown]
# ![image.png](attachment:6b92f864-cab7-418a-aaaf-cea0ee943d6b.png)

# %% [markdown]
# ##### __2.4 Generacion de calor en un solido__
#
# La generación de calor suele expresarse por unidad de volumen del medio y se denota por e · gen, cuya unidad es W/m3. Por ejemplo, la generación de calor en un alambre eléctrico de radio exterior r0 y longitud L se puede expresar como;

# %% [markdown]
# \begin{equation}
#     \dot{e}_{gen} = \frac{\dot{E}_{gen,electrica}}{V_{alambre}} = \frac{I^2 R_e}{\pi r_o^2 L}
# \end{equation}

# %% [markdown]
# La temperatura de un medio se eleva durante la generación de calor, como resultado de la absorción del calor generado por el medio durante el periodo transitorio de arranque. Amedida que se incrementa la temperatura del medio, también aumenta la transferencia de calor de ese medio hacia sus alrededores. Esto continúa hasta que se alcanzan las condiciones de operación estacionarias
# y la velocidad de generación de calor es igual a la razón de la transferencia de calor hacia los alrededores. Una vez que se ha establecido la operación estacionaria, la temperatura del medio en cualquier punto ya no cambia.
# La temperatura máxima Tmáx en un sólido que comprende generación uniforme de calor se tiene en un lugar lo más alejado de la superficie exterior, cuando ésta se mantiene a una temperatura constante Ts.

# %% [markdown]
# \begin{equation}
#     \dot{Q} = \dot{e}_{gen} V
# \end{equation}

# %% [markdown]
# ##### __2.5 Conduccion de calor transitorio__
#
# Considere un cuerpo de forma arbitraria y masa m, volumen V, área superficial As, densidad r y calor específico Cp, inicialmente a una temperatura Ti. En el instante t _ 0, el cuerpo está colocado en un medio a la temperatura T_ y se lleva a efecto transferencia de calor entre ese cuerpo y su medio ambiente, con un coeficiente de transferencia de calor h. En beneficio de la discusión, se supondrá que T_ _ Ti, pero el análisis es igualmente válido para el caso opuesto. Se supondrá que el análisis de sistemas concentrados es
# aplicable, de modo que la temperatura permanece uniforme dentro del cuerpo en todo momento y sólo cambia con el tiempo, T _ T(t). Durante un intervalo diferencial de tiempo, dt, la temperatura del cuerpo se eleva en una cantidad diferencial dT. Un balance de energía del sólido para el intervalo de tiempo dt se puede expresar como;

# %% [markdown]
# \begin{equation}
#     hA_s\left(T_\infty - T\right)dt = mc_p dT
# \end{equation}

# %% [markdown]
# \begin{equation}
#     \frac{d\left(T - T_\infty\right)}{T - T_\infty} = -{\frac{hA_s}{\rho V c_p}}dt
# \end{equation}

# %% [markdown]
# \begin{equation}
#     ln\frac{T_\left(t\right) - T_\infty}{T_i - T_\infty} = -{\frac{hA_s}{\rho V c_p}}t
# \end{equation}

# %% [markdown]
# ##### __2.6 Conduccion de calor en regimen transitorio__
#
# Se aplica el método de las diferencias finitas a los problemas de estado estacionario mediante la diferenciación del problema en las variables espaciales
# y resolviendo para las temperaturas en distintos puntos llamados nodos. La solución obtenida es válida para cualquier instante, dado que en condiciones estacionarias las temperaturas no cambian con el tiempo.
# las temperaturas cambian con el tiempo así como con la posición y, de este modo, la solución en diferencias finitas de este tipo de problemas requiere la diferenciación en el tiempo y el espacio, como se muestra en la figura;
#
# ![image.png](attachment:6cbfa1b5-1331-4cb1-84ff-b4415c52c4c7.png)

# %% [markdown]
# La formulación en los problemas de conducción de calor en régimen transitorio difiere de los de estado estacionario en que los primeros comprenden un término adicional que represente el cambio en el contenido de energía del medio con el tiempo. Este término adicional aparece como una primera derivada de la temperatura con respecto al tiempo en la ecuación diferencial, y como un cambio en el contenido de energía interna durante _t en la formulación del balance de energía. Los nodos y los elementos de volumen en los problemas en régimen transitorio se seleccionan igual que en los de estado estacionario y, una vez más, si se supone por conveniencia que toda la transferencia de calor es hacia el elemento, el balance de energía sobre un elemento de volumen durante un intervalo de tiempo _t se puede expresar como;

# %% [markdown]
# \begin{equation}
#     \delta t \times\sum_{todos los lados} \dot{Q} + \delta t \times \dot{E}_{gen,elemento} = \delta E_{elemento}
# \end{equation}

# %% [markdown]
# donde la razón de la transferencia de calor, Q, normalmente consta de términos de conducción para los nodos interiores, pero puede comprender convección,
# flujo de calor y radiación para los nodos frontera.
# Dado que _Eelemento _ mcp_T _ rVelemento cp_T, donde r es la densidad y cp es el calor específico del elemento, al dividir la relación anterior entre _t da;

# %% [markdown]
# \begin{equation}
#     \sum_{todos los lados} \dot{Q} + \dot{E}_{gen,elemento} = \frac{\delta E_{elemento}}{\delta t} = \rho V_{elemento} c_p \frac{\delta T}{\delta t}
# \end{equation}

# %% [markdown]
# para cualquier nodo m en el medio y su elemento de volumen,
#
# \begin{equation}
#     \sum_{todos los lados} \dot{Q} + \dot{E}_{gen,elemento} = \frac{\delta E_{elemento}}{\delta t} = \rho V_{elemento} c_p \frac{T^{i+1}_m - T^i_m}{\delta t}
# \end{equation}

# %% [markdown]
# ![image.png](attachment:43c0f576-e372-4b93-8176-e5ecb6784a7a.png)

# %% [markdown]
# ###### Perfil de temperatura placa plana
#
# ![image.png](attachment:a6a502a9-b41b-4857-bfd4-a21dd3a0bd6d.png)

# %% [markdown]
# ###### __Conduccion de calor en regimen transitorio en solidos semiinfinitos__
#
# Un sólido semiinfinito es un cuerpo idealizado que tiene una sola superficie plana y se extiende hacia el infinito en todas direcciones, este cuerpo idealizado se usa para indicar que el cambio de temperatura en la parte del cuerpo en la que se interesa (la región cercana a la superficie) se debe a las condiciones térmicas en una sola superficie
#
# ![image.png](attachment:89c16bd8-3340-4383-89d7-076e2bf6f61f.png)

# %% [markdown]
# ##### __2.7 Método(s), metodología__
#
# En primera instancia se observa la importancia de los fundamentos técnicos-teóricos basados en las practicas ingenieriles, he aquí donde encontramos una separación entre sus métodos que aunque exista una gran brecha de separacion para nuestro caso se encuentra muy arriagada y en definitiva ayudara a furutos ingenieros en complementar sus funcionalidades con el manejo actualizado de nuevas tecnologias permitiendo fluir hacia la tendencia mundial, hoy en dia en su triunfo (₂ al satisfacer las necesidades de las personas que lo usan, trabajar sin fallos durante largos periodos, será fácil de modificar e incluso más fácil de usar) como lo es su finalidad de diseño en la mejora constante, y  de utilidad para quien conoce su potencial, permitiendo consigo ser oportuno en un enfoque de ingenieria.
#
#
# Este modelo de proceso, manejo de sotfware como herramienta se muestra  eficaz al momento de interpretar informacion y dictatoria de resultados.
#
#
# Se presentan los metodos de analisis y diseño con tecnicas orientadas a sistemas de control para los procesos lo que nos permite observar las variaciones dentro de las propiedades mecanicas del objeto estudiado y su rendimiento a traves del tiempo.
#
#
# Con los valores supuestos de los parametros y datos de propiedades de los materiales a utlizar, se denota un ejemplo en especifico para relizar nuestro laboratorio con las condiciones dadas.
#
#
# Teniendo esta informacion de los valores relativos  se procede a modelar matematicamente mediante software PYTHON en un entorno difuso que facilmente puede ser modificado para cualquier sin numero de situaciones; donde las variables y todos los coeficientes, facilmente se pueden cambiar para simular el momentos de complejidad y dar una resolucion de forma dinamica, tambien sirve de planificador frente a las principales intuiciones por parte del observador; De modo que se puede hacer dicho control y analizar como es el comportamiento de la temperatura trayendo consigo las soluciones de manera mas apropiada para un funcionamiento pleno.

# %% [markdown]
# ##### __2.8 Ejemplificacion__
#
# ![image.png](attachment:285163c0-b90e-4691-beb2-e7ed2a763a19.png)
#
# Algunas indicaciones y para los cálculos:
#
# •	Temperatura de pared (suponer) ejemplo; 62°C temp. Inicial. Uniforme en el líquido. Setpoint (sistema de control automático) hasta temp 58°C y encienda la resistencia que ajuste o reponga el calor que perdió. Tomar pared vertical o cilindro, temp máx en el centro.
#
# •	Parte superior placa plana (convección natural), el termo está abierto al ambiente.
#
# •	Material altamente conductor y delgado (grosor).
#
# •	Solido con diferentes temp. (se está enfriando).
#
# / Métodos a utilizar; puede ser analítico, métodos numéricos o transitorio.

# %% [markdown]
# ##### __- Diseño modelado en AutoCAD__
#
# Considere un diseño basado en el mas simple vaso termico de estructura metalica que en su interior mantiene un liquido caliente y a su vez interactua con el ambiente. Para tener una idealizacion; se hacen despreciables los materiales y sus propiedades, como tambien factores externos que puedan afectar nuestra representacion en este caso academico.

# %% [markdown]
# ###### - Seccion longitudinal
#
# ![image.png](attachment:fa2f3fe5-6f9c-44b1-aa5f-54c9078dfc51.png)

# %% [markdown]
# ##### __2.9 Resultados__
#
#
# Se logra  recepcion conjunto a los resultados obtenidos, se implemento algunas operaciones algebraicas sencillas…
#
#
# Se muestran a continuacion las operaciones y los resultados analizados en PYTHON
#
#
#
#
# Despues de correr el programa, arroja los resultados del rango permitido del contro de temperatura
#
#
# Muestra de rendimiento de la temperatura en el tiempo como funcion
# .

# %% [markdown]
# ##### __3. Conclusiones__
#
#
# Este artículo presenta una técnica moderna de implementación de nuevas herramientas tecnológicas con un enfoque ingenieril de los procesos actualmente utilizados en la industria, al incentivar a otras aspiraciones como crear nuevos códigos a partir de investigaciones avanzadas, siguiendo con la idea del progreso que en Colombia partiendo de los conocimientos que le anteceden se mantiene la búsqueda de nuevos métodos que faciliten y contribuyan al bien vivir del hombre.

# %% [markdown]
# ##### - __Referencias__
# Libro Cengel
#
# Libros
#
# Formato base
#
# [1] N.N. Cengel, Transferencia de calor. Ciudad, País: Editorial, año.
#
# Ejemplo:
#
# [1] K.C. Budka, J.G. Deshpande y M. Thottan, Communication Networks for Smart Grids: Making Smart Grid Real. UK: Springer-Verlag, 2014.
